# %% [markdown]
# # Amazon Alexa Sentiment Analysis

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, ImageColorGenerator
import string
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
from spacy import displacy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, average_precision_score,auc
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
import sklearn.metrics as metrics

#import en_core_web_sm

plt.style.use('fivethirtyeight')

# %%
#reading file
df=pd.read_csv("amazon_alexa.tsv",sep="\t",encoding="ISO-8859-1")
df.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
# rating              3150 non-null int64
# date                3150 non-null object
# variation           3150 non-null object
# verified_reviews    3150 non-null object
# feedback            3150 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 123.1+ KB

# %%
df.shape
# Out:
# (3150, 5)

# %%
df.describe()
# Out:
#             rating     feedback
# count  3150.000000  3150.000000
# mean      4.463175     0.918413
# std       1.068506     0.273778
# min       1.000000     0.000000
# 25%       4.000000     1.000000
# 50%       5.000000     1.000000
# 75%       5.000000     1.000000
# max       5.000000     1.000000

# %%
df.isna().mean(axis=0)
# Out:
# rating              0.0
# date                0.0
# variation           0.0
# verified_reviews    0.0
# feedback            0.0
# dtype: float64

# %%
df['feedback'].value_counts()
# Out:
# 1    2893
# 0     257
# Name: feedback, dtype: int64

# %%
#plt.figure(figsize=(15,5))
ax=sns.countplot(data=df,x='feedback');
#for p, label in zip(ax.patches, df["feedback"].value_counts().index):
 #   ax.annotate(label, (p.get_x()+0.375, p.get_height()+0.15))
ax.set_xticks(np.arange(10))
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
df['feedback'].mean()
# Out:
# 0.9184126984126985

# %% [markdown]
# 91% of the data has positive reviews

# %%
#seeing the distribution of word length
df['review_length']=df['verified_reviews'].apply(len)

#fig = plt.figure(1, figsize=(10,6))
sns.distplot(df['review_length'],kde=False);
plt.axvline(x=df['review_length'].mean(), ymin=0,ymax=1);

# %%
df['review_length'].mean()
# Out:
# 132.50063492063492

# %% [markdown]
# Avergae review length is around 132 words.

# %%
df['date']=pd.to_datetime(df['date'], format="%d-%b-%y")
df.dtypes
# Out:
# rating                       int64
# date                datetime64[ns]
# variation                   object
# verified_reviews            object
# feedback                     int64
# review_length                int64
# dtype: object

# %%
plt.figure(figsize=(15,5))
ax=sns.countplot(df['date'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
np.random.seed(10)
sns.set(rc={'figure.figsize':(14,8)})
reviews = ' '.join(df['verified_reviews'].tolist())

wordcloud = WordCloud(background_color="white").generate(reviews)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.title('Reviews',size=20)
plt.show()

# %%
df_positive=df[df['feedback']==1]
sns.set(rc={'figure.figsize':(14,8)})
reviews = ' '.join(df_positive['verified_reviews'].tolist())

wordcloud = WordCloud(background_color="white").generate(reviews)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.title('Reviews',size=20)
plt.show()

# %% [markdown]
# Mostly contains words such as alexa, love,music,one,speaker,good,device,great

# %%
df_negative=df[df['feedback']==0]
sns.set(rc={'figure.figsize':(14,8)})
reviews = ' '.join(df_negative['verified_reviews'].tolist())

wordcloud = WordCloud(background_color="white").generate(reviews)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.title('Reviews',size=20)
plt.show()

# %% [markdown]
# Contains words like never,disappointed,tried,problem,still.

# %%
sns.violinplot(df['feedback'], df['rating'], palette = 'cool');

# %% [markdown]
# ### Tokenizing data with NLTK

# %% [markdown]
# Let's create a custom function using NLTK which will automatically strip words that we dont need. Few of these words include stopwords, punctuations, special characters.

# %% [markdown]
# #### Tokenization

# %%
punctuations = string.punctuation
df['verified_reviews'] = df.verified_reviews.apply(lambda x: x.lower())
df['verified_reviews'] = df.verified_reviews.apply(lambda x: ''.join([c for c in x if c not in punctuation]))
word_tokenize(df.verified_reviews[0])
# Out:
# ['love', 'my', 'echo']

# %%
sw = set(stopwords.words('english'))

df['token_reviews'] = df.verified_reviews.apply(lambda x: word_tokenize(x))
df['clean_reviews'] = df.token_reviews.apply(lambda x : [word for word in x if word not in sw] )
df['clean_reviews'] = df.clean_reviews.apply(lambda x : " ".join(x))
df.head()
# Out:
#    rating       date         variation  \
# 0       5 2018-07-31  Charcoal Fabric
# 1       5 2018-07-31  Charcoal Fabric
# 2       4 2018-07-31    Walnut Finish
# 3       5 2018-07-31  Charcoal Fabric
# 4       5 2018-07-31  Charcoal Fabric
#
#                                     verified_reviews  feedback  review_length  \
# 0                                       love my echo         1             13
# 1                                           loved it         1              9
# 2  sometimes while playing a game you can answer ...         1            195
# 3  i have had a lot of fun with this thing my 4 y...         1            172
# 4                                              music         1              5
#
#                                        token_reviews  \
# 0                                   [love, my, echo]
# 1                                        [loved, it]
# 2  [sometimes, while, playing, a, game, you, can,...
# ...

# %% [markdown]
# ## Classification

# %%
#train test split with 70-30%
y=df['feedback']
X_train, X_test, y_train, y_test = train_test_split(df["clean_reviews"], y, test_size=0.3,random_state=10)

# %% [markdown]
#  ### Forming the Bag of words

# %%
# Initialize a CountVectorizer object: count_vectorizer
count_vectorizer = CountVectorizer(stop_words="english")

# Transform the training data using only the 'text' column values: count_train 
count_train = count_vectorizer.fit_transform(X_train)
y_train = np.asarray(y_train.values)

ch2 = SelectKBest(chi2, k = 300)

X_new = ch2.fit_transform(count_train, y_train)

# Transform the test data using only the 'text' column values: count_test 
count_test = count_vectorizer.transform(X_test)

X_test_new = ch2.transform(X=count_test)

# %% [markdown]
# ### Implementing TF-IDF vectorization

# %%
count_vectorizer = CountVectorizer(stop_words="english")

def TextPreprocessor(train,train_y,test):
        
    CountVectorizer(stop_words="english")
    count = count_vectorizer.fit_transform(train)
    count_test = count_vectorizer.transform(X_test)
    
    tfidf_vectorizer = TfidfTransformer()
    tfidf = tfidf_vectorizer.fit_transform(count)
    tfidf_test = tfidf_vectorizer.transform(count_test)
    
    ch2 = SelectKBest(chi2, k = 300)
    
    X_new = ch2.fit_transform(count_train, y_train)
    
    train_new = ch2.fit_transform(tfidf, y_train)
    test_new = ch2.transform(tfidf_test)
    
    return train_new, test_new

# %%
train_set, test_set = TextPreprocessor(X_train, y_train, X_test)

# %% [markdown]
# ### 1. Naive Baye's classification

# %%
#Building a Naive bayes classifier for classification

gnb_classifier = GaussianNB()

#fitting train data in the classifier
gnb_classifier.fit(train_set.todense(), y_train)
gnb_classifier.score(train_set.todense(), y_train)
# Out:
# 0.9823129251700681

# %%
#Testing our classifier onto test data and storing the results in y_pred variable
y_pred_train= gnb_classifier.predict(train_set.todense())
y_pred = gnb_classifier.predict(test_set.todense())

# %%
#in sample metrics
score = metrics.accuracy_score(y_train, y_pred_train)
print('In-sample Accuracy is:',score)

pscore = metrics.precision_score(y_train, y_pred_train)
print('In-sample precision is:',pscore)

f1 = metrics.f1_score(y_train, y_pred_train)
print('In-sample F score is:',f1)

auc = metrics.roc_auc_score(y_train, y_pred_train)
print('In-sample AUC score is:',auc)
# Out:
# In-sample Accuracy is: 0.9823129251700681
# In-sample precision is: 0.982030111704711
# In-sample F score is: 0.9904481998530491
# In-sample AUC score is: 0.8972959841023737

# %%
#Checking accuracy of predictions on test data
#We are using confusion matrix from sklearn.metrics
cm = confusion_matrix(y_test,y_pred)
print((cm[0,0]+cm[1,1])/cm.sum()*100)
score = metrics.accuracy_score(y_test, y_pred)
print('Out of sample Accuracy is:',score)

pscore = metrics.precision_score(y_test, y_pred)
print('Out of sample precision is:',pscore)

f1 = metrics.f1_score(y_test, y_pred)
print('Out of sampleF score is:',f1)

auc = metrics.roc_auc_score(y_test, y_pred)
print('Out of sample  AUC score is:',auc)

sns.heatmap(metrics.confusion_matrix(y_pred,y_test),annot=True,fmt='2.0f');
# Out:
# 91.42857142857143
# Out of sample Accuracy is: 0.9142857142857143
# Out of sample precision is: 0.9508009153318078
# Out of sampleF score is: 0.9535283993115319
# Out of sample  AUC score is: 0.6952410514202652

# %% [markdown]
# ### 2. Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(LogisticRegression(), param_grid, cv=5)
grid.fit(train_set, y_train)

print("Best cross-validation score: {:.2f}".format(grid.best_score_))
print("Best parameters: ", grid.best_params_)
print("Best estimator: ", grid.best_estimator_)
# Out:
# Best cross-validation score: 0.93
# Best parameters:  {'C': 10}
# Best estimator:  LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
# C:\Users\ambit\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
lr = grid.best_estimator_
lr.fit(train_set, y_train)
lr_pred_train=lr.predict(train_set)
lr_pred=lr.predict(test_set)
#print("Score: {:.2f}".format(lr.score(test_set, y_test)))

# %%
#in sample metrics
score = metrics.accuracy_score(y_train, lr_pred_train)
print('In-sample Accuracy is:',score)

pscore = metrics.precision_score(y_train, lr_pred_train)
print('In-sample precision is:',pscore)

f1 = metrics.f1_score(y_train, lr_pred_train)
print('In-sample F score is:',f1)

auc = metrics.roc_auc_score(y_train, lr_pred_train)
print('In-sample AUC score is:',auc)
# Out:
# In-sample Accuracy is: 0.9714285714285714
# In-sample precision is: 0.9698131288931481
# In-sample F score is: 0.984675261493554
# In-sample AUC score is: 0.8259668508287292

# %%
#out of sample
score = metrics.accuracy_score(y_test, lr_pred)
print('Out of sample Accuracy is:',score)

pscore = metrics.precision_score(y_test, lr_pred)
print('Out of sample precision is:',pscore)

f1 = metrics.f1_score(y_test, lr_pred)
print('Out of sampleF score is:',f1)

auc = metrics.roc_auc_score(y_test, lr_pred)
print('Out of sample  AUC score is:',auc)

sns.heatmap(metrics.confusion_matrix(y_pred,lr_pred),annot=True,fmt='2.0f');
# Out:
# Out of sample Accuracy is: 0.9312169312169312
# Out of sample precision is: 0.9331896551724138
# Out of sampleF score is: 0.9638286032276016
# Out of sample  AUC score is: 0.5903791411786082

# %% [markdown]
# ### 3. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics as metrics

rf_clf = RandomForestClassifier(random_state=10)
# Fit the classifier to the training data
rf_clf.fit(train_set, y_train)

# Create the predicted tags: pred
pred_rf = rf_clf.predict(test_set)
pred_rf_train = rf_clf.predict(train_set)
# Out:
# C:\Users\ambit\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
sns.heatmap(metrics.confusion_matrix(pred_rf,y_test),annot=True,fmt='2.0f');

# %%
randfor_clf = RandomForestClassifier()
metrics_score = metrics.make_scorer(metrics.fbeta_score, beta=0.5)
parameters = {'n_estimators': [150, 180, 250], 'max_features': [120,150], 'max_depth': [120,135,150],'min_samples_split':[3,5],'min_samples_leaf':[1,3,5]}

grid_obj = GridSearchCV(randfor_clf, parameters, scoring=metrics_score)

grid_fit = grid_obj.fit(X_new, y_train)
# Out:
# C:\Users\ambit\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
best_randforclf = grid_fit.best_estimator_
best_predictions_train = best_randforclf.predict(X_new)
best_predictions = best_randforclf.predict(X_test_new)

# %%
#in sample metrics
score = metrics.accuracy_score(y_train, best_predictions_train)
print('In-sample Accuracy is:',score)

pscore = metrics.precision_score(y_train, best_predictions_train)
print('In-sample precision is:',pscore)

f1 = metrics.f1_score(y_train, best_predictions_train)
print('In-sample F score is:',f1)

auc = metrics.roc_auc_score(y_train, best_predictions_train)
print('In-sample AUC score is:',auc)
# Out:
# In-sample Accuracy is: 0.981859410430839
# In-sample precision is: 0.9806201550387597
# In-sample F score is: 0.9902152641878669
# In-sample AUC score is: 0.8895027624309393

# %%
#out of sample
score = metrics.accuracy_score(y_test, best_predictions)
print('Out of sample Accuracy is:',score)

pscore = metrics.precision_score(y_test, best_predictions)
print('Out of sample precision is:',pscore)

f1 = metrics.f1_score(y_test, lr_pred)
print('Out of sampleF score is:',f1)

auc = metrics.roc_auc_score(y_test, best_predictions)
print('Out of sample  AUC score is:',auc)
# Out:
# Out of sample Accuracy is: 0.9259259259259259
# Out of sample precision is: 0.9404630650496141
# Out of sampleF score is: 0.9638286032276016
# Out of sample  AUC score is: 0.635530858215735

# %%
sns.heatmap(metrics.confusion_matrix(pred_rf,best_predictions),annot=True,fmt='2.0f', cmap="RdGy")

# %% [markdown]
# ### 4. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

from itertools import compress

features = count_vectorizer.get_feature_names()
mask = ch2.get_support()
features = list(compress(features, mask))
importances = best_randforclf.feature_importances_

tree_model = DecisionTreeClassifier(random_state=0, max_depth=5, min_samples_split=5).fit(X_new, y_train)

# %%
import os
os.environ["PATH"] += os.pathsep+r"C:\Graphviz\release\bin"
from sklearn import tree
import graphviz

tree_graph = tree.export_graphviz(tree_model, feature_names=features)
graphviz.Source(tree_graph)

# %%
tree_predictions = tree_model.predict(X_test_new)
tree_train_predictions = tree_model.predict(X_new)

score = metrics.accuracy_score(y_train, tree_train_predictions)
print('Accuracy is:',score)

pscore = metrics.precision_score(y_train, tree_train_predictions)
print('In-sample precision is:',pscore)

f1 = metrics.f1_score(y_train, tree_train_predictions)
print('In-sample F score is:',f1)

auc = metrics.roc_auc_score(y_train, tree_train_predictions)
print('In-sample AUC score is:',auc)
# Out:
# Accuracy is: 0.9315192743764172
# In-sample precision is: 0.9325635103926097
# In-sample F score is: 0.9639532107901646
# In-sample AUC score is: 0.5954499050073154

# %%
# Calculate the accuracy score: score
score = metrics.accuracy_score(y_test, tree_predictions)
print('Accuracy is:',score)

pscore = metrics.precision_score(y_test, tree_predictions)
print('Precision is:',f1)

f1 = metrics.f1_score(y_test, tree_predictions)
print('F score is:',f1)

auc = metrics.roc_auc_score(y_test, tree_predictions)
print('AUC score is:',auc)
# Out:
# Accuracy is: 0.9227513227513228
# Precision is: 0.9639532107901646
# F score is: 0.9593314763231198
# AUC score is: 0.5677654291078674

# %%
sns.heatmap(metrics.confusion_matrix(y_test,tree_predictions),annot=True,fmt='2.0f', cmap="RdGy");

# %% [markdown]
# ### 4. SVM

# %%
from sklearn import svm
# Perform classification with SVM, kernel=linear
classifier_linear = svm.SVC(kernel='linear')
classifier_linear.fit(train_set, y_train)
prediction_linear = classifier_linear.predict(test_set)
prediction_linear_train = classifier_linear.predict(train_set)

# %%
score = metrics.accuracy_score(y_train, prediction_linear_train)
print('Accuracy is:',score)

pscore = metrics.precision_score(y_train, prediction_linear_train)
print('In-sample precision is:',pscore)

f1 = metrics.f1_score(y_train, prediction_linear_train)
print('In-sample F score is:',f1)

auc = metrics.roc_auc_score(y_train, prediction_linear_train)
print('In-sample AUC score is:',auc)
# Out:
# Accuracy is: 0.9287981859410431
# In-sample precision is: 0.9280146721687299
# In-sample F score is: 0.9626634958382877
# In-sample AUC score is: 0.5662983425414365

# %%
# Calculate the accuracy score: score
score = metrics.accuracy_score(y_test, prediction_linear)
print('Accuracy is:',score)

pscore = metrics.precision_score(y_test, prediction_linear)
print('Precision is:',f1)

f1 = metrics.f1_score(y_test, prediction_linear)
print('F score is:',f1)

auc = metrics.roc_auc_score(y_test, prediction_linear)
print('AUC score is:',auc)
# Out:
# Accuracy is: 0.9206349206349206
# Precision is: 0.9626634958382877
# F score is: 0.9586321014892444
# AUC score is: 0.506578947368421

# %%
sns.heatmap(metrics.confusion_matrix(y_test,prediction_linear),annot=True,fmt='2.0f', cmap="RdGy");

# %% [markdown]
# ### 5. Neural network

# %%
from keras.layers import Dense, Input, Flatten
from keras.layers import GlobalAveragePooling1D, Embedding
from keras.models import Model
from keras import metrics
EMBEDDING_DIM = 50
N_CLASSES = 1
MAX_SEQUENCE_LENGTH = 300
MAX_NB_WORDS = 20000

# input: a sequence of MAX_SEQUENCE_LENGTH integers
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')

embedding_layer = Embedding(MAX_NB_WORDS, EMBEDDING_DIM,
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=True)
embedded_sequences = embedding_layer(sequence_input)

average = GlobalAveragePooling1D()(embedded_sequences)
predictions = Dense(N_CLASSES, activation='softmax')(average)

model = Model(sequence_input, predictions)
model.compile(loss='binary_crossentropy',
              optimizer='adam', metrics=['acc',metrics.binary_accuracy])
# Out:
# Using TensorFlow backend.

# %%
model.fit(train_set, y_train, validation_split=0.1,
          nb_epoch=10, batch_size=128)
# Out:
# C:\Users\ambit\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#
# C:\Users\ambit\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 1984 samples, validate on 221 samples
# Epoch 1/10
# 1984/1984 [==============================] - 1s 259us/step - loss: 1.2288 - acc: 0.9199 - binary_accuracy: 0.9199 - val_loss: 1.5180 - val_acc: 0.9005 - val_binary_accuracy: 0.9005
# Epoch 2/10
# 1984/1984 [==============================] - 0s 202us/step - loss: 1.2288 - acc: 0.9199 - binary_accuracy: 0.9199 - val_loss: 1.5180 - val_acc: 0.9005 - val_binary_accuracy: 0.9005
# Epoch 3/10
# ...

# %%
scores= model.evaluate(test_set, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 91.96%
